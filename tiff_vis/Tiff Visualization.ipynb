# %%
import numpy as np
from osgeo import gdal
import matplotlib.pyplot as plt

# %%
path = './ES709_2005.tif'

# %%
ds = gdal.Open(path)

# %%
im = ds.ReadAsArray()

# %%
im = np.nan_to_num(im)

# %%
np.min(im), np.max(im)
# Out:
# (0.0, 0.46224123)

# %%
from skimage import data, io
# Out:
# (2188, 2986, 3)

# %%
plt.imshow(np.stack(im, axis=2))
