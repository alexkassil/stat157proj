# %%
import numpy as np
from osgeo import gdal
import matplotlib.pyplot as plt

# %%
path = './ES709_2005.tif'

# %%
ds = gdal.Open(path)
ds
# Out:
# <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0x7fc4149104b0> >

# %%
im = ds.ReadAsArray()

# %%
im = np.nan_to_num(im)

# %%
np.min(im), np.max(im)
# Out:
# (0.0, 0.46224123)

# %%
im.shape
# Out:
# (3, 2188, 2986)

# %%
from skimage import data, io

# %%
io.imshow(np.stack(im, axis=2))

# %%
ratio = float(224/max(im.shape))
ratio
im.resize((3, int(ratio * im.shape[1]), int(ratio * im.shape[2])), refcheck=False)
